# %% [markdown]
# <a href="https://colab.research.google.com/github/Hristo2076/it-s-the-math/blob/main/f(x).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Уровень 0:**

# %% [markdown]
# **Задание 1** \
# Посчитайте значение первой и второй производной функции: \
# $f(x) = x^5 + 4sin(2x) + cos(3x+3)$ \
# В точке x = 1.

# %%
import numpy as np
from sympy import diff, cos, sin,Symbol
from matplotlib import pyplot as plt
from sympy.solvers.solveset import linsolve

# %%
x = Symbol('x')

# %%
y = x**5 + 4 * sin(2*x) + cos(3*x+3)
y_dif = y.diff(x)
y_dif_2 = y_dif.diff(x)

print(f'First derivative: {y_dif}')
print(f'Second derivative: {y_dif_2}')


res_1 = diff(y).evalf(subs={x:1})
res_2 = diff(res_1).evalf(subs={x:1})

print(f'resoult 1: {res_1} \nresoult 2: {res_2}')
# Out:
# First derivative: 5*x**4 - 3*sin(3*x + 3) + 8*cos(2*x)
# Second derivative: 20*x**3 - 16*sin(2*x) - 9*cos(3*x + 3)
# resoult 1: 2.50907180221964
# resoult 2: 0

# %% [markdown]
# #**Уровень 1:**

# %% [markdown]
# **Задание 2** \
# Постройте график первой и второй производной функции: \
# $f(x) = sin^5(2x+1)$ \
# На отрезке [-5; 5].

# %%
def diff_(x):
  x = Symbol('x')
  y1 = sin(2 * x + 1)** 5
  res = diff(y)
  res_1 = diff(res)
  return res , res_1

diff_(x)
# Out:
# (5*x**4 - 3*sin(3*x + 3) + 8*cos(2*x), 20*x**3 - 16*sin(2*x) - 9*cos(3*x + 3))

# %%
x = np.arange(-5,5,0.01)
y = 5*x**4 - 3*np.sin(3*x + 3) + 8*np.cos(2*x)

# %%
x1 = np.arange(-5,5,0.01)
y1 = 20*x**3 - 16*np.sin(2*x) - 9*np.cos(3*x + 3)

# %%
plt.plot(x,y)
plt.plot(x,5*x**4 - 3*np.sin(3*x + 3) + 8*np.cos(2*x))
plt.xlabel('x')
plt.ylabel('y')
plt.ylim([0, 10])
plt.xlim([-5, 5]) 
plt.show()

# %%
plt.plot(x1,y1)
plt.plot(x,20*x**3 - 16*np.sin(2*x) - 9*np.cos(3*x + 3))
plt.xlabel('x')
plt.ylabel('y')
plt.ylim([-20, 20])
plt.xlim([-5, 5]) 
plt.show()
